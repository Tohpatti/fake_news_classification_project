# %%
# !pip3 install newspaper3k
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 KB 5.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 KB 7.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 58.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 KB 5.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13552 sha256=bfa3a2683359a9e80128151b9e58b39d489039dc91cffeb0255b0e179c81f9c2
#   Stored in directory: /root/.cache/pip/wheels/99/74/83/8fac1c8d9c648cfabebbbffe97a889f6624817f3aa0bbe6c09
# ...

# %%
from newspaper import Article, ArticleException
from bs4 import BeautifulSoup
from csv import writer
import pandas as pd
import nltk
import requests
import re
import os

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# # **CNN Indonesia**

# %%
links = []

# %%
# rentang waktu 23 Desember 2022 hingga 30 Desember 2022 diakses pada 13 Januari 2023 pukul 13.55 WIB
for i in range(401,600):
  url = f"https://www.cnnindonesia.com/indeks/2/{i}/"
  page = requests.get(url)

  soup = BeautifulSoup(page.content, 'lxml')

  for article in soup.findAll('article'): # ('article',{'class': '...'}) jika terdapat nama kelas spesifik yang diinginkan
    for a in article.findAll('a'):
      links.append(article.a['href'])

links

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path = "/content/drive/MyDrive/fake_news_classification_project/Datasets/real_news.csv"

# %%
# write new CSV file
with open(path, 'w', encoding='utf8', newline='') as f:
  thewriter = writer(f)
  header = ['Judul', 'Teks', 'Publikasi', 'Ringkasan', 'URL']
  thewriter.writerow(header)

  for link in links:
    try:
      # get the article
      article = Article(link)

      # do some NLP
      article.download()
      article.parse()
      article.nlp()

      # get the information in article
      title = article.title
      text = article.text
      publish = article.publish_date
      summary = article.summary

      # input the information into csv
      info = [title, text, publish, summary, link]
      thewriter.writerow(info)

    except ArticleException:
      pass

# %% [markdown]
# # **Liputan 6**

# %%
links = []

# %%
# rentang waktu xx Desember 2022 hingga xx Januari 2023 diakses pada 16 Januari 2023 pukul 11.00 WIB
news_cat = ["politik", "peristiwa", "megapolitan", "rajut"]
for i in news_cat:
  url = f"https://www.liputan6.com/news/{i}/"
  page = requests.get(url)

  soup = BeautifulSoup(page.content, 'lxml')

  for article in soup.findAll('article', {'class' : 'articles--iridescent-list--item articles--iridescent-list--text-item'}):
    links.append(article.a['href'])

# %%
# rentang waktu xx Desember 2022 hingga xx Januari 2023 diakses pada 16 Januari 2023 pukul 11.00 WIB
bisnis_cat = ["ekonomi", "bank", "energi-tambang"]
for i in news_cat:
  url = f"https://www.liputan6.com/bisnis/{i}/"
  page = requests.get(url)

  soup = BeautifulSoup(page.content, 'lxml')

  for article in soup.findAll('article', {'class' : 'articles--iridescent-list--item articles--iridescent-list--text-item'}):
    links.append(article.a['href'])

# %%
# rentang waktu xx Desember 2022 hingga xx Januari 2023 diakses pada 16 Januari 2023 pukul 11.00 WIB
bola_cat = ["sports", "corner"]
for i in news_cat:
  url = f"https://www.liputan6.com/bola/{i}/"
  page = requests.get(url)

  soup = BeautifulSoup(page.content, 'lxml')

  for article in soup.findAll('article', {'class' : 'articles--iridescent-list--item articles--iridescent-list--text-item'}):
    links.append(article.a['href'])

# %%
# rentang waktu xx Desember 2022 hingga xx Januari 2023 diakses pada 16 Januari 2023 pukul 11.00 WIB
showbiz_cat = ["celeb", "musik", "film", "kpop", "hollywood", "indie"]
for i in news_cat:
  url = f"https://www.liputan6.com/showbiz/{i}/"
  page = requests.get(url)

  soup = BeautifulSoup(page.content, 'lxml')

  for article in soup.findAll('article', {'class' : 'articles--iridescent-list--item articles--iridescent-list--text-item'}):
    links.append(article.a['href'])

# %%
# rentang waktu xx Desember 2022 hingga xx Januari 2023 diakses pada 16 Januari 2023 pukul 11.00 WIB
tekno_cat = ["gadget", "apps", "internet", "berita", "telko"]
for i in news_cat:
  url = f"https://www.liputan6.com/tekno/{i}/"
  page = requests.get(url)

  soup = BeautifulSoup(page.content, 'lxml')

  for article in soup.findAll('article', {'class' : 'articles--iridescent-list--item articles--iridescent-list--text-item'}):
    links.append(article.a['href'])

# %%
# rentang waktu xx Desember 2022 hingga xx Januari 2023 diakses pada 16 Januari 2023 pukul 11.00 WIB
lifestyle_cat = ["kuliner", "travel", "home-decor"]
for i in news_cat:
  url = f"https://www.liputan6.com/news/{i}/"
  page = requests.get(url)

  soup = BeautifulSoup(page.content, 'lxml')

  for article in soup.findAll('article', {'class' : 'articles--iridescent-list--item articles--iridescent-list--text-item'}):
    links.append(article.a['href'])

# %%
# rentang waktu xx Desember 2022 hingga xx Januari 2023 diakses pada 16 Januari 2023 pukul 11.00 WIB
health_cat = ["health-info", "fit-diet", "persona", "mom-kids", "konsultasi-psikologi"]
for i in news_cat:
  url = f"https://www.liputan6.com/news/{i}/"
  page = requests.get(url)

  soup = BeautifulSoup(page.content, 'lxml')

  for article in soup.findAll('article', {'class' : 'articles--iridescent-list--item articles--iridescent-list--text-item'}):
    links.append(article.a['href'])

# %%
with open(path, 'a', newline='') as f:
  thewriter = writer(f)

  for link in links:
    try:
      # get the article
      article = Article(link)

      # do some NLP
      article.download()
      article.parse()
      article.nlp()

      # get the information in article
      title = article.title
      text = article.text
      publish = article.publish_date
      summary = article.summary

      # input the information into csv
      info = [title, text, publish, summary, link]
      thewriter.writerow(info)

    except ArticleException:
      pass

# %%
df = pd.read_csv(path)
df # rentang waktu 16 Desember 2022 hingga 16 Januari 2023 diakses pada 16 Januari 2023 pukul 13.00 WIB

# %% [markdown]
# # **Detik**

# %%
links = []

# %%
# rentang waktu 14 Januari 2023 hingga 21 Januari 2023 diakses pada 21 Januari 2023 pukul 16.10 WIB
for i in range(2,115):
  url = f"https://news.detik.com/indeks/{i}/"
  page = requests.get(url)

  soup = BeautifulSoup(page.content, 'lxml')

  for article in soup.findAll('h3', {'class' : 'media__title'}):
    links.append(article.a['href'])

# %%
with open(path, 'a', newline='') as f:
  thewriter = writer(f)

  for link in links:
    try:
      # get the article
      article = Article(link)

      # do some NLP
      article.download()
      article.parse()
      article.nlp()

      # get the information in article
      title = article.title
      text = article.text
      publish = article.publish_date
      summary = article.summary

      # input the information into csv
      info = [title, text, publish, summary, link]
      thewriter.writerow(info)

    except ArticleException:
      pass

# %%
df = pd.read_csv(path)
df
